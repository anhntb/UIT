# %% [markdown]
# # Basic types

# %%
# int a = 1;
a = 3
print(type(a))

b = 5.5
print(type(b))

c = a + b

print(a+b)
# Out:
# <class 'int'>
# <class 'float'>
# 8.5

# %%
print("tín" + str(1))
# Out:
# tín1

# %%
print(2**3)
# Out:
# 8

# %%
type(c)
# Out:
# float

# %%
s = "Statistical Machine Learning"
m = str(a) + s
m
# Out:
# '3Statistical Machine Learning'

# %%
type(s)
# Out:
# str

# %%
len(s)
# Out:
# 28

# %%
# mac dinh tach ra thanh tung phan tu theo khoang trang
s.split()
# Out:
# ['Statistical', 'Machine', 'Learning']

# %%
s2 = "Statistical / Machine / Learning"

# %%
s2.split()
# Out:
# ['Statistical', '/', 'Machine', '/', 'Learning']

# %%
s2.split("/")
# Out:
# ['Statistical ', ' Machine ', ' Learning']

# %%
print("hello world")
print('hello world')

#cả hai dấy là chuỗi
# Out:
# hello world
# hello world

# %%
print('hello' + 'world')
print("hello" * 3)
print("==="*20)
print(2**10)
# Out:
# helloworld
# hellohellohello
# ...
# 1024

# %%
# đếm chữ số trong một chữ số
print(len(str(2 ** 10)))
# Out:
# 4

# %%
# Tìm giá trị nhỏ nhất
a = (2, 3, 1)
print(type(a))
min(a)
# Tìm giá trị lớn nhất
max(a)
# Out:
# <class 'tuple'>
# 3

# %% [markdown]
# # Mutation types

# %% [markdown]
# ## List
#
# List sử dụng dấu []

# %%
# tuong tu array
a = [1,2,-1,3,4,5,1,1,2,-1]

# %%
len(a)
# Out:
# 10

# %%
a[1:4]
# Out:
# [2, -1, 3]

# %%
a.append(10)
a
# Out:
# [1, 2, -1, 3, 4, 5, 1, 1, 2, -1, 10]

# %%
a + [10]
# Out:
# [1, 2, -1, 3, 4, 5, 1, 1, 2, -1, 10, 10]

# %%
a.clear()

# %%
a
# Out:
# []

# %% [markdown]
# Truy xuất ngược

# %%
b = ["tin","khanh","đẹp trai", [1,2, "tin"]]
b
# Out:
# ['tin', 'khanh', 'đẹp trai', [1, 2, 'tin']]

# %% [markdown]
# ## Set
# Set sử dụng dấu {}

# %%
s = {1,1,-2,3,1,4,6,6,6,6,6,6,6}

# %%
s
# Out:
# {-2, 1, 3, 4, 6}

# %%
#làm sao để tìm được số lượng các phần
#  tử duy nhất trong list bên dưới?
ls = [1,2,3,5,4,4,4,5,5]


a = 1
print(type(a))

b = float(a)

print(type(b))

# ép kiểu
ls = list(set(ls))
len(ls)
# Out:
# <class 'int'>
# <class 'float'>
# 5

# %%
import numpy as np

ls = np.unique(ls)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 import numpy as np
#       3 ls = np.unique(ls)
#
# ModuleNotFoundError: No module named 'numpy'

# %%
print(ls)

# %% [markdown]
# Kết hợp list vs set

# %%
l = [1, 2, 3, [3, 4, 8.3, {2,3,4}], {3,4,5}, 'Hông pé ơi']

# for (int i=0; i<len(l); i++) - cu phap c++
# for i in range(0, len(l)): # cu phap python
#     print(l[i])

for i in l:
  print(i)

# %%
for i in l:
  print(i)

# %%
s = {1,1,-2,3,1,4,6,6,6,6,6,6,6}
for i in s:
  print(i)

# %% [markdown]
# ## Tuples
# Tuple sử dụng dấu ()

# %%
t = (1,)
print(type(t))

# %%
len(t)

# %%
t2 = ( (1,2), (1, [1,3,5]), ([3,5,6], {1,2,4}, 5) )

# %%
len(t2)

# %%
t2[2][1]

# %%
t2[2]

# %% [markdown]
# ## Dictionary
# Dictionary sử dụng cặp key - value để biểu diễn dữ liệu

# %%
dc = {
    'val1': 7,
    'val1': 5,
    'val3': (1,2),
    'val4': [1,3,2],
    'val5': {1,3,4},
    'val6': (1, [3,4], {2,1}, (4,6,7)),
}

# %%
dc

# %%
dc['val1']

# %%
dc['val7'] = (3,42, 46 )

# %%
dc

# %%
dc['val5']

# %%
dc['val5']

# %%
dc.items()

# %%
for k, v in dc.items():
    print("key: "+ k)
    print("val: {}".format(v))
    print("type: {}".format(type(v)))

# %% [markdown]
# # If, For, While

# %%
# duyet theo index

l = [1,2,-1,3,4,5,1,1,2,-1]

for i in range(0, len(l)):
    # print("index: {}".format(i))
    print("index: {}".format(i))
    print(l[i])

# %%
len(l)

# %%
s = "a"
v = "b"
t = "3"

a =1

print("dnajsbcia  " + str(a))

print("Gia tri 1: {}, gia tri 2: {}, gia tri 3: {}".format(s, v, t))

# %%
print("Gia tri 1: "+s+", gia tri 2" + v)

# %%
# Duyet tung phan tu
for e in l:
    print(e)

# %%
# Duyet tung phan tu trong tap hop
s = {1,1,-2,3,1,4,6}

for e in s:
    print(e)

# %%
l = [1, [1,23]]

# %%
t = ( (1,2), (1, [1,3,5]), ([3,5,6], {1,2,4}, 5) )

# %%
for i in range(0, len(t)):
    print(t[i])

# %%
# Thao tac voi chuoi

s = "Statistical Machine Learning"

for i in s:
  print(i)

# %%
for i in range(0, len(s)):
    if s[i].isupper():
      print(s[i])

# %%
# Su dung while
# qua trinh chia batch
# du lieu ban dau duoc chia thanh cac batch voi kich thuoc bang nhau

N = 1000
batch = 128

while N > 0:
    if ((N - batch) >= 0):
        print(batch)
    else:
        print(N)
    N = N - batch

# %%
n = -1
while n>0:
    # print(n)
    # n -=1
    pass

c = 3 + 4

# %% [markdown]
# # Program structure

# %%
def tinhtong(a,b):
    pass

# %%
def sum(a,b):
    return a+b

# %%
sum(4,-1)

# %%
def sum2(a,b):
    return(a+b)

# %%
c = sum2(4,5)

# %%
print(c)

# %%
s = "Statistical Machine Learning"

def segment(s):
    return s.split()

segment(s)

# %%
def segment2(s, return_string):
    split_string = s.split()

    if return_string == True:
        return s, split_string

    return split_string

# %%
st, st1= segment2(s, return_string=True)
print(st1)

# %%
st = segment2(s, return_string=False)
print(st)

# %%
lst

# %%
def segment3(s, return_string=False):
    if return_string:
        return s, len(s), s.split(), len(s.split())
    return s.split(), len(s.split())

# %%
segment3(s, return_string=True)

# %%
# Full program

def segment(s):
    return s.split()

def segment2(s, return_string=False):
    if return_string:
        return s, s.split()
    return s.split()

def segment3(s, return_string=False):
    if return_string:
        return s, len(s), s.split(), len(s.split())
    return s.split(), len(s.split())



# Ham main
# tuong tu void main() trong c++
if __name__ == '__main__':
    s = "Statistical Machine Learning"

    original_string, token_list = segment2(s, return_string=True)

    print("chuoi ban dau: {}".format(original_string))
    print("chuoi da tach tu: {}".format(token_list))

    print(__name__)

# %% [markdown]
# # Class

# %%
class Student:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def handsome_level(self):
        if (self.age > 20):
          return self.name + ' with ' + str(self.age) + ' years old is handsome'
        else:
          return self.name + ' with ' + str(self.age) + ' years old is ugly'

# %%
st = Student("Tín",25)

print(st.name)
print(st.age)
print(st.handsome_level())

# %%
class Tokenizer:
    def __init__(self):
        self._tokenized_list = []

    def tokenize(self, s):
        self._tokenized_list = s.split()
        return self._tokenized_list

    @property
    def list_token(self):
        return self._tokenized_list

    @property
    def number_of_words(self):
        return len(self._tokenized_list)

# %%
tokenizer = Tokenizer()

s = "Statistical Machine Learning"
tokenizer.tokenize(s)

# %%
lst_word = tokenizer.list_token
num_word = tokenizer.number_of_words

# %%
lst_word

# %%
num_word

# %%
lst = Tokenizer().tokenize("Xin lũi mình dùng python, được hông ?")

# %%
lst

# %% [markdown]
# # Doc du lieu CSV

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
'/content/drive/MyDrive/chest_xray/test/NORMAL/IM-0001-0001.jpeg'

# %%
import pandas as pd

data = pd.read_csv('/content/drive/MyDrive/Giảng dạy/Học máy thống kê/Cũ/Thực hành lớp .12/house_price/housing.csv')
type(data)

# %%
data.head(10)

# %%
len(data)

# %%
data.columns.values

# %%
type(data.columns.values)

# %%
list_column = data.columns.values.tolist()
list_column

# %%
list_column[:-2]

# %%
data.loc[:, ['longitude', 'latitude']]

# %%
list_column[0:3]

# %%
data.loc[:, list_column[0:3]]

# %%
list_column[:-1]

# %%
import numpy
